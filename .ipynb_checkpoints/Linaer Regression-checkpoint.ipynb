# %% [markdown]
# # Import the files

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# # Now loading the datasets
# This will done by using pandas

# %%
diabetes = datasets.load_diabetes()
type(data)
X = diabetes.data
Y = diabetes.target

# %%
df = pd.DataFrame(X)
new_columns = diabetes.feature_names
df.columns = new_columns
type(X)
# Out:
# numpy.ndarray

# %% [markdown]
# # Training Section
# In this we will traing the algorithm using the sklearn inbuilt linear regression

# %%
model = LinearRegression()
model.fit(X,Y)
y_pred = model.predict(X)
plt.scatter(Y,y_pred)
plt.axis([0,300,0,300])
plt.show()
